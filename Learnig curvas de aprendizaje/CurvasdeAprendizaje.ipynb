# %% [markdown]
# # Curvas de aprendizaje
#
# Pamela Cerdas Matamoros

# %% [markdown]
# # ¿Cómo enfrentar el problema de sesgo alto? (High bias)
#
# - Incrementar la complejidad del modelo
# - Ténicas de regularización
# - Modificar la partición de los datos del conjunto inicial
# - Prepocesamiento
# - Agregar factores que ayuden a explicar la variable de salida

# %% [markdown]
# # Explicacion
# 1. Incrementar la complejidad del modelo
#
# Si el modelo es muy simple, debes hacerlo más flexible.
#
# Ejemplos:
#
# Pasa de RL a RP.
# Aumenta la profundidad de un árbol de decisión con datos.
# Agrega más neuronas o capas en una red neuronal, mas entrenamiento.
#
#
# 2. Técnicas de regularización
#
# Aquí hay que tener cuidado.
#
# La regularización (Lasso, Ridge) normalmente se usa para evitar el sobreajuste (high variance).
#
# Si hay mucho sesgo:
#
# Porque reduce la regularización puede ayuda al modelo.
# Una regularización excesiva puede hacer el modelo demasiado simple y limitado.
#
#
# 3. La partición de los datos modificarla
#
# Se revisa de que manera se dividieron los datos:
# A veces un conjunto de entrenamiento muy pequeño provoca un aprendizaje deficiente.
#
# 4. Preprocesamiento
#
# Preparar mejor los datos antes de entrenar.
#
# Ejemplos:
#
# Eliminar datos erróneos.
# Tratar valores faltantes.
# Escalar variables.
# Codificar variables categóricas.
#
# 5. Agregar factores explicativos
#
# Agregar variables relevantes.
#
# Ejemplo:
#
# Si quieres predecir el consumo de limón y solo usas ingreso:
# Consumo = f(Ingreso)
#
# Precio del limón
# 2
# Precio de sustitutos
# 3
# Población
# 4
# Estación del año
# 5
# Exportaciones

# %% [markdown]
# ## ¿Cómo enfrentar el problema del varianza alta? (high variance)
#
# - Preprocesamiento
# - Regularizar
# - Mayor cantidad de epocas
# - Agregar mas datos
# - Simplificar el modelo
# - Batch (lotes) / early Stopping

# %% [markdown]
# # Alta varianza?
#
# Ocurre cuando el modelo aprende demasiado bien los datos de entrenamiento, incluso el ruido y no predice de manera correcta.
#
# Error de entrenamiento muy bajo.
# Error de validación/prueba alto.
#
# Esto se llama sobreajuste (overfitting).
#
# Por ejemplo:
# Entrenamiento: 98% de precisión
# Prueba:        70% de precisión
#
# 1. Preprocesamiento
#
# Preparar mejor los datos antes de entrenar.
#
# Ejemplos:
#
# Eliminar datos erróneos.
# Tratar valores faltantes.
# Escalar variables.
# Eliminar variables irrelevantes.
#
# 2. Regularizar
#
# La regularización penaliza modelos demasiado complejos.
#
# Ejemplos:
#
# Ridge (L2)
# Lasso (L1)
#
# La idea es agregar una penalización para evitar que los coeficientes se vuelvan exageradamente grandes.
#
# 3. Mayor cantidad de épocas
#
# Ojo: esto no siempre reduce la varianza.
#
# Una época es una pasada completa por los datos.
#
# Si el modelo aún no ha aprendido bien, aumentar épocas puede ayudar.
#
# Pero si ya existe overfitting:
#
# Más épocas pueden empeorarlo.
#
# Por eso normalmente se combina con Early Stopping.
#
# 4. Agregar más datos
#
# Es una de las mejores soluciones.
#
# Ejemplo:
# 100 observaciones  → modelo inestable
# 1000 observaciones → modelo más robusto
#
# 5. Simplificar el modelo
#
# Si el modelo es demasiado complejo:
#
# Menos variables.
# Menor profundidad del árbol.
# Menos capas en una red neuronal.
# Menor grado de un polinomio.
#
# 6. Batch (lotes) / Early Stopping
# Batch
#
# Divide los datos en grupos pequeños para entrenar.
#
# Ejemplo:
# 1000 registros
# Batch = 100

# %%
import numpy as np

import pandas as pd

import seaborn as sns 

import matplotlib.pyplot as plt 

 

from sklearn.model_selection import train_test_split
from sklearn.model_selection import validation_curve

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

 

from sklearn.impute import SimpleImputer

from sklearn.preprocessing import MinMaxScaler, OneHotEncoder

 

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold

# %%
# leyendo y cargando los datos:

 

mypath = "https://archive.ics.uci.edu/ml/machine-learning-databases/statlog/australian/australian.dat"

data = pd.read_csv(mypath, sep=" ", header=None)

data.columns = ['A1','A2','A3','A4','A5','A6','A7','A8','A9','A10','A11','A12','A13','A14','class']

 

# Algunos ajustes previos con datos categóricos con niveles de muy baja frecuencia con fines didácticos:

data['A4'] = data['A4'].map({2:2, 1:0, 3:0})

data['A5'] = data['A5'].map({1:1,2:0,3:3,4:4,5:0,6:6,7:7,8:8,9:9,10:0,11:11,12:0,13:13,14:14})

data['A6'] = data['A6'].map({1:1,2:0,3:0,4:4,5:5,7:0,8:8,9:0})

 

# Definimos nuestros datos de entrada, de salida y la partición correspondiente:

X = data.iloc[:,:-1]  

Y = data.iloc[:,-1]      

 

Xtv, Xtest, ytv, ytest = train_test_split(X, Y, test_size=0.2, random_state=1)  

print(Xtv.shape, ': dimensión de datos de entrada de entrenamiento y validación')

print(Xtest.shape, ': dimensión de datos de entrada de prueba')  

print(ytv.shape, ': dimensión de variable de salida para entrenamiento y validación')

print(ytest.shape, ': dimensión de variable de salida para prueba')
# Out:
# (552, 14) : dimensión de datos de entrada de entrenamiento y validación
# (138, 14) : dimensión de datos de entrada de prueba
# (552,) : dimensión de variable de salida para entrenamiento y validación
# (138,) : dimensión de variable de salida para prueba

# %% [markdown]
# Base completa:      690 observaciones
#
# Entrenamiento:
# 552 observaciones
# 14 variables
#
# Prueba:
# 138 observaciones
# 14 variables
#
# Base completa: 690 registros
#
# divide
#
# 552 registros (80%)
# para aprender
#
# 138 registros (20%)
# para hacer el examen

# %%
# Transformaciones a factores numéricos de entrada:

num_pipeline = Pipeline(steps = [('impMediana', SimpleImputer(strategy='median')),

                                 ('escalaNum', MinMaxScaler(feature_range=(1,2)))])   

num_pipeline_nombres = ['A2','A3','A7','A10','A13','A14']

 

# Transformaciones a factores categóricos de entrada:

catImp_pipeline = Pipeline(steps = [('impModa', SimpleImputer(strategy='most_frequent'))])  

catImp_pipeline_nombres = ['A1', 'A4', 'A5', 'A6', 'A8', 'A9', 'A11', 'A12']

 

# Transformaciones one-hot-encoder en algunas de las categóricas:

catOHE_pipeline = Pipeline(steps = [('OneHotE', OneHotEncoder(drop='first'))])

catOHE_pipeline_nombres = [ 'A4','A5','A6','A12']

 

# Conjuntamos las transformaciones numéricas y categóricas que se estarán aplicando a los datos de entrada:

columnasTransformer = ColumnTransformer(transformers = [('numpipe', num_pipeline, num_pipeline_nombres),

                                                        ('catimp', catImp_pipeline, catImp_pipeline_nombres),

                                                        ('catohe', catOHE_pipeline, catOHE_pipeline_nombres)],

                                        remainder='passthrough')

# %%
delta_C = np.linspace(.0001, 200., 20)

 

modelo = LogisticRegression(penalty='l2', 
                            max_iter=10000,
                            solver='liblinear',
                            random_state=1)

 

Xx = columnasTransformer.fit_transform(Xtv)

 

cvLC = RepeatedStratifiedKFold(n_splits=10, n_repeats=5, random_state=11)

# Importar validation_curve aquí para asegurar que esté disponible si no se rerunearon las celdas de importación
from sklearn.model_selection import validation_curve

 

train_scores, valid_scores = validation_curve(modelo, 
                                              Xx, 
                                              np.ravel(ytv), 
                                              param_name="C", 
                                              param_range=delta_C,
                                              cv=cvLC,
                                              scoring='accuracy')

 

 

train_mean = np.mean(train_scores, axis=1)

train_std = np.std(train_scores, axis=1)

valid_mean = np.mean(valid_scores, axis=1)

valid_std = np.std(valid_scores, axis=1)

 

 

# Curva de entrenamiento con la métrica de exactitud (accuracy):

plt.plot(delta_C, train_mean, color='blue', marker='o', markersize=5, label='Training')

 

# Curva de validación:

plt.plot(delta_C, valid_mean, color='red', marker='o', markersize=5, label='Validation')

 

plt.title('Función validation_curve()')

plt.xlabel('Valores del parámetro C de regularization $L_2$')

plt.ylabel('Exactitud')

plt.grid()

plt.legend(loc='lower right')

plt.show()
# Out:
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
# ...

# %%
# Salvo el primer valor, el modelo se mantiene casi constante tanto para

# los datos de entrenamiento como de validación:

 

print('Valor promedio de los resultados con los conjuntos de entrenamiento: %.3f' % train_mean[1:20].mean())

print('Valor promedio de los resultados con los conjuntos de validación: %.3f' % valid_mean[1:20].mean())
# Out:
# Valor promedio de los resultados con los conjuntos de entrenamiento: 0.873
# Valor promedio de los resultados con los conjuntos de validación: 0.844

# %%
modeloLC = LogisticRegression(penalty='l2', 

                              max_iter=10000,

                              C=100.,

                              solver='liblinear',

                              random_state=1)

# %%
delta_train_sz = np.linspace(0.1, 1.0, 20)

 

cvLC = RepeatedStratifiedKFold(n_splits=10, n_repeats=5, random_state=11)

# Importar learning_curve aquí para asegurar que esté disponible si no se rerunearon las celdas de importación
from sklearn.model_selection import learning_curve

 

train_sizes, train_scores, valid_scores = learning_curve(estimator=modeloLC, 
                                                        X=Xx, 
                                                        y=np.ravel(ytv),
                                                        cv=cvLC, 
                                                        train_sizes=delta_train_sz,
                                                        scoring='accuracy')

 

 

# Obtengamos la gráfica de las curvas de aprendizaje 

# cuando se incrementa el tamaño de la muestra:

 

train_mean = np.mean(train_scores, axis=1)

train_std = np.std(train_scores, axis=1)

valid_mean = np.mean(valid_scores, axis=1)

valid_std = np.std(valid_scores, axis=1)

 

plt.plot(train_sizes, train_mean, color='blue', marker='o', markersize=5, label='Training')

 

plt.plot(train_sizes, valid_mean, color='red', marker='o', markersize=5, label='Validation')

 

plt.title('Función learning_curve()')

plt.xlabel('Tamaño del conjunto de entrenamiento')

plt.ylabel('Exactitud (accuracy)')

plt.grid()

plt.legend(loc='lower right')

plt.show()
# Out:
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
#   warnings.warn(
# c:\Users\Usuario\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\linear_model\_logistic.py:1403: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', l1_ratio set to a float between 0 and 1 instead of penalty='elasticnet', and C=np.inf instead of penalty=None.
# ...
